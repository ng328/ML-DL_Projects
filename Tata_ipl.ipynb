# %% [markdown]
# <a href="https://colab.research.google.com/github/ng328/ML-DL_Projects/blob/main/Tata_ipl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/sample_data/IPL Auction 2022.csv")
df
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
df.head()
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M        R Ashwin         India              TNCA   35
# 1        1        M     Trent Boult   New Zealand               NaN   32
# 2        1        M     Pat Cummins     Australia               NaN   28
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 1       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# 2  ALL-ROUNDER     RHB        RIGHT ARM Fast   37.0         DD, MI, KKR
# 3      BATSMAN     LHB                     -  192.0    DCH, MI, SRH, DC
# 4      BATSMAN     RHB    RIGHT ARM Leg Spin  100.0            RPS, CSK
#
#   2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
df.tail()
# Out:
#      Set No. Set Name           Player Country State Association  Age  \
# 179       53     UAL8       Ansh Patel   India               BCA   20
# 180       54     UFA8     Ashok Sharma   India               RCA   19
# 181       57    UAL10  Arjun Tendulkar   India               MCA   22
# 182       59    UAL12  Shubham Garhwal   India               RCA   26
# 183       60    UAL13     Anunay Singh   India              BICA   29
#
#       Specialism Batting                   Bowling  IPL Previous IPLTeam(s)  \
# 179  ALL-ROUNDER     RHB  LEFT ARM Slow Unorthodox  NaN                 NaN
# 180       BOWLER     RHB     RIGHT ARM Fast Medium  NaN                 NaN
# 181  ALL-ROUNDER     LHB      LEFT ARM Fast Medium  0.0                  MI
# 182  ALL-ROUNDER     LHB    LEFT ARM Slow Orthodox  NaN                 NaN
# 183  ALL-ROUNDER     RHB     RIGHT ARM Fast Medium  NaN                 NaN
#
#     2021 Team     C/U/A Base Price Sold Price          New Franchise
# ...

# %%
df.head(10)
# Out:
#    Set No. Set Name           Player       Country State Association  Age  \
# 0        1        M         R Ashwin         India              TNCA   35
# 1        1        M      Trent Boult   New Zealand               NaN   32
# 2        1        M      Pat Cummins     Australia               NaN   28
# 3        1        M   Shikhar Dhawan         India              DDCA   36
# 4        1        M   Faf Du Plessis  South Africa               NaN   37
# 5        1        M     Shreyas Iyer         India               MCA   27
# 6        1        M    Kagiso Rabada  South Africa               NaN   26
# 7        1        M   Mohammad Shami         India               CAB   32
# 8        1        M     David Warner     Australia               NaN   35
# 9        2      BA1  Shimron Hetmyer   West Indies               NaN   25
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# ...

# %%
df.size
# Out:
# 2944

# %%
df.shape
# Out:
# (184, 16)

# %%
df.ndim
# Out:
# 2

# %%
df.values
# Out:
# array([[1, 'M', 'R Ashwin', ..., '2 CR', '5 CR', 'Rajasthan Royals'],
#        [1, 'M', 'Trent Boult', ..., '2 CR', '8 CR', 'Rajasthan Royals'],
#        [1, 'M', 'Pat Cummins', ..., '2 CR', '7.25 CR',
#         'Kolkata Knight Riders'],
#        ...,
#        [57, 'UAL10', 'Arjun Tendulkar', ..., '20 L', '30 L',
#         'Mumbai Indians'],
#        [59, 'UAL12', 'Shubham Garhwal', ..., '20 L', '20 L',
#         'Rajasthan Royals'],
#        [60, 'UAL13', 'Anunay Singh', ..., '20 L', '20 L',
#         'Rajasthan Royals']], dtype=object)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
df.head(5)
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M        R Ashwin         India              TNCA   35
# 1        1        M     Trent Boult   New Zealand               NaN   32
# 2        1        M     Pat Cummins     Australia               NaN   28
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 1       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# 2  ALL-ROUNDER     RHB        RIGHT ARM Fast   37.0         DD, MI, KKR
# 3      BATSMAN     LHB                     -  192.0    DCH, MI, SRH, DC
# 4      BATSMAN     RHB    RIGHT ARM Leg Spin  100.0            RPS, CSK
#
#   2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
df['Player']
# Out:
# 0             R Ashwin
# 1          Trent Boult
# 2          Pat Cummins
# 3       Shikhar Dhawan
# 4       Faf Du Plessis
#             ...
# 179         Ansh Patel
# 180       Ashok Sharma
# 181    Arjun Tendulkar
# 182    Shubham Garhwal
# 183       Anunay Singh
# Name: Player, Length: 184, dtype: object

# %%
df[['Player','Country']]
# Out:
#               Player       Country
# 0           R Ashwin         India
# 1        Trent Boult   New Zealand
# 2        Pat Cummins     Australia
# 3     Shikhar Dhawan         India
# 4     Faf Du Plessis  South Africa
# ..               ...           ...
# 179       Ansh Patel         India
# 180     Ashok Sharma         India
# 181  Arjun Tendulkar         India
# 182  Shubham Garhwal         India
# 183     Anunay Singh         India
#
# [184 rows x 2 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=184, step=1)

# %%
df["Age"].sum()
# Out:
# 4987

# %%
df["Age"][0]
# Out:
# 35

# %%
df.loc[0,"Age"]
# Out:
# 35

# %%
df.iloc[0]
# Out:
# Set No.                                 1
# Set Name                                M
# Player                           R Ashwin
# Country                             India
# State Association                    TNCA
# Age                                    35
# Specialism                    ALL-ROUNDER
# Batting                               RHB
# Bowling                RIGHT ARM Off Spin
# IPL                                 167.0
# Previous IPLTeam(s)    CSK, RSP, KXIP, DC
# 2021 Team                              DC
# C/U/A                              Capped
# Base Price                           2 CR
# Sold Price                           5 CR
# New Franchise            Rajasthan Royals
# Name: 0, dtype: object

# %%
df.loc[0,"Player"]
# Out:
# 'R Ashwin'

# %%
df.loc[df["Age"]>35]
# Out:
#     Set No. Set Name          Player       Country State Association  Age  \
# 3         1        M  Shikhar Dhawan         India              DDCA   36
# 4         1        M  Faf Du Plessis  South Africa               NaN   37
# 14        2      BA1   Robin Uthappa         India               KCA   36
# 15        3      AL1    Dwayne Bravo   West Indies               NaN   38
# 25        4      WK1  Dinesh Karthik         India              TNCA   36
# 28        4      WK1   Ambati Rayudu         India               ACA   36
#
#       Specialism Batting                Bowling    IPL  \
# 3        BATSMAN     LHB                      -  192.0
# 4        BATSMAN     RHB     RIGHT ARM Leg Spin  100.0
# 14       BATSMAN     RHB                      -  193.0
# 15   ALL-ROUNDER     RHB  RIGHT ARM Fast Medium  151.0
# 25  WICKETKEEPER     RHB                      -  213.0
# 28  WICKETKEEPER     RHB                      -  175.0
#
# ...

# %%
df.loc[(df['Age']>30) & (df['Country']=='India')]
# Out:
#      Set No. Set Name             Player Country State Association  Age  \
# 0          1        M           R Ashwin   India              TNCA   35
# 3          1        M     Shikhar Dhawan   India              DDCA   36
# 7          1        M     Mohammad Shami   India               CAB   32
# 12         2      BA1      Manish Pandey   India              KSCA   32
# 14         2      BA1      Robin Uthappa   India               KCA   36
# 19         3      AL1      Krunal Pandya   India               BCA   31
# 20         3      AL1      Harshal Patel   India               HCA   31
# 25         4      WK1     Dinesh Karthik   India              TNCA   36
# 28         4      WK1      Ambati Rayudu   India               ACA   36
# 34         5      FA1  Bhuvneshwar Kumar   India              UPCA   32
# 38         5      FA1        Umesh Yadav   India               VCA   34
# 39         6      SP1   Yuzvendra Chahal   India               HCA   31
# ...

# %%
df.loc[(df['Country']=='India') & (df['Age']>30)]
# Out:
#      Set No. Set Name             Player Country State Association  Age  \
# 0          1        M           R Ashwin   India              TNCA   35
# 3          1        M     Shikhar Dhawan   India              DDCA   36
# 7          1        M     Mohammad Shami   India               CAB   32
# 12         2      BA1      Manish Pandey   India              KSCA   32
# 14         2      BA1      Robin Uthappa   India               KCA   36
# 19         3      AL1      Krunal Pandya   India               BCA   31
# 20         3      AL1      Harshal Patel   India               HCA   31
# 25         4      WK1     Dinesh Karthik   India              TNCA   36
# 28         4      WK1      Ambati Rayudu   India               ACA   36
# 34         5      FA1  Bhuvneshwar Kumar   India              UPCA   32
# 38         5      FA1        Umesh Yadav   India               VCA   34
# 39         6      SP1   Yuzvendra Chahal   India               HCA   31
# ...

# %%
df.loc[df["Country"]=="India"]
# Out:
#      Set No. Set Name            Player Country State Association  Age  \
# 0          1        M          R Ashwin   India              TNCA   35
# 3          1        M    Shikhar Dhawan   India              DDCA   36
# 5          1        M      Shreyas Iyer   India               MCA   27
# 7          1        M    Mohammad Shami   India               CAB   32
# 11         2      BA1  Devdutt Padikkal   India              KSCA   21
# ..       ...      ...               ...     ...               ...  ...
# 179       53     UAL8        Ansh Patel   India               BCA   20
# 180       54     UFA8      Ashok Sharma   India               RCA   19
# 181       57    UAL10   Arjun Tendulkar   India               MCA   22
# 182       59    UAL12   Shubham Garhwal   India               RCA   26
# 183       60    UAL13      Anunay Singh   India              BICA   29
#
#       Specialism Batting                   Bowling    IPL Previous IPLTeam(s)  \
# ...

# %%
df.isnull()
# Out:
#      Set No.  Set Name  Player  Country  State Association    Age  Specialism  \
# 0      False     False   False    False              False  False       False
# 1      False     False   False    False               True  False       False
# 2      False     False   False    False               True  False       False
# 3      False     False   False    False              False  False       False
# 4      False     False   False    False               True  False       False
# ..       ...       ...     ...      ...                ...    ...         ...
# 179    False     False   False    False              False  False       False
# 180    False     False   False    False              False  False       False
# 181    False     False   False    False              False  False       False
# 182    False     False   False    False              False  False       False
# 183    False     False   False    False              False  False       False
#
# ...

# %%
df.fillna(0)
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand                 0   32
# 2          1        M      Pat Cummins     Australia                 0   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa                 0   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
df.describe()
# Out:
#           Set No.         Age         IPL
# count  184.000000  184.000000  137.000000
# mean    17.989130   27.103261   36.897810
# std     14.200742    4.428570   46.902635
# min      1.000000   17.000000    0.000000
# 25%      7.000000   24.000000    3.000000
# 50%     14.500000   27.000000   21.000000
# 75%     25.000000   30.250000   50.000000
# max     60.000000   38.000000  213.000000

# %%
df.dropna()
# Out:
#      Set No. Set Name               Player Country State Association  Age  \
# 0          1        M             R Ashwin   India              TNCA   35
# 3          1        M       Shikhar Dhawan   India              DDCA   36
# 5          1        M         Shreyas Iyer   India               MCA   27
# 7          1        M       Mohammad Shami   India               CAB   32
# 11         2      BA1     Devdutt Padikkal   India              KSCA   21
# ..       ...      ...                  ...     ...               ...  ...
# 135       25     UAL3         Pravin Dubey   India              KSCA   28
# 137       25     UAL3  Suyash Prabhudessai   India               GCA   24
# 142       27     UFA3        Vaibhav Arora   India              HPCA   24
# 145       27     UFA3          Mohsin Khan   India              UPCA   23
# 181       57    UAL10      Arjun Tendulkar   India               MCA   22
#
#       Specialism Batting                Bowling    IPL Previous IPLTeam(s)  \
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# Length: 184, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
  df.tail(-4)
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# 5          1        M     Shreyas Iyer         India               MCA   27
# 6          1        M    Kagiso Rabada  South Africa               NaN   26
# 7          1        M   Mohammad Shami         India               CAB   32
# 8          1        M     David Warner     Australia               NaN   35
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
df.loc[(df['Specialism']=="BATSMAN") & (df['Batting']=='LHB')]
# Out:
#      Set No. Set Name            Player       Country State Association  Age  \
# 3          1        M    Shikhar Dhawan         India              DDCA   36
# 8          1        M      David Warner     Australia               NaN   35
# 9          2      BA1   Shimron Hetmyer   West Indies               NaN   25
# 10         2      BA1      David Miller  South Africa               NaN   32
# 11         2      BA1  Devdutt Padikkal         India              KSCA   21
# 96        16     UBA2       Rinku Singh         India              UPCA   24
# 111       19      BA3      Devon Conway   New Zealand               NaN   30
# 113       19      BA3        Evin Lewis   West Indies               NaN   30
# 156       32     UBA4      Rahul Buddhi         India              HYCA   24
# 169       47     UBA6      Ramesh Kumar         India               PCA   23
# 170       47     UBA6     Pratham Singh         India              RSPB   29
#
# ...

# %%
 df.loc[[0,1]]
# Out:
#    Set No. Set Name       Player      Country State Association  Age  \
# 0        1        M     R Ashwin        India              TNCA   35
# 1        1        M  Trent Boult  New Zealand               NaN   32
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 1       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
#
#   2021 Team   C/U/A Base Price Sold Price     New Franchise
# 0        DC  Capped       2 CR       5 CR  Rajasthan Royals
# 1        MI  Capped       2 CR       8 CR  Rajasthan Royals

# %%
df.loc[0]
# Out:
# Set No.                                 1
# Set Name                                M
# Player                           R Ashwin
# Country                             India
# State Association                    TNCA
# Age                                    35
# Specialism                    ALL-ROUNDER
# Batting                               RHB
# Bowling                RIGHT ARM Off Spin
# IPL                                 167.0
# Previous IPLTeam(s)    CSK, RSP, KXIP, DC
# 2021 Team                              DC
# C/U/A                              Capped
# Base Price                           2 CR
# Sold Price                           5 CR
# New Franchise            Rajasthan Royals
# Name: 0, dtype: object

# %%
df
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
df.loc[0]
# Out:
# Set No.                                 1
# Set Name                                M
# Player                           R Ashwin
# Country                             India
# State Association                    TNCA
# Age                                    35
# Specialism                    ALL-ROUNDER
# Batting                               RHB
# Bowling                RIGHT ARM Off Spin
# IPL                                 167.0
# Previous IPLTeam(s)    CSK, RSP, KXIP, DC
# 2021 Team                              DC
# C/U/A                              Capped
# Base Price                           2 CR
# Sold Price                           5 CR
# New Franchise            Rajasthan Royals
# Name: 0, dtype: object

# %%
df=pd.DataFrame(data=df,index=['a','b','c'])

# %%
df
# Out:
#    Set No. Set Name Player Country State Association  Age Specialism Batting  \
# a      NaN      NaN    NaN     NaN               NaN  NaN        NaN     NaN
# b      NaN      NaN    NaN     NaN               NaN  NaN        NaN     NaN
# c      NaN      NaN    NaN     NaN               NaN  NaN        NaN     NaN
#
#   Bowling  IPL Previous IPLTeam(s) 2021 Team C/U/A Base Price Sold Price  \
# a     NaN  NaN                 NaN       NaN   NaN        NaN        NaN
# b     NaN  NaN                 NaN       NaN   NaN        NaN        NaN
# c     NaN  NaN                 NaN       NaN   NaN        NaN        NaN
#
#   New Franchise
# a           NaN
# b           NaN
# c           NaN

# %%
df[df['New Franchise']=='Rajasthan Royals']
# Out:
#      Set No. Set Name               Player      Country State Association  \
# 0          1        M             R Ashwin        India              TNCA
# 1          1        M          Trent Boult  New Zealand               NaN
# 9          2      BA1      Shimron Hetmyer  West Indies               NaN
# 11         2      BA1     Devdutt Padikkal        India              KSCA
# 33         5      FA1      Prasidh Krishna        India              KSCA
# 39         6      SP1     Yuzvendra Chahal        India               HCA
# 55         8     UAL1          Riyan Parag        India              ASCA
# 82        13      AL2        James Neesham  New Zealand               NaN
# 87        14      FA2  Nathan Coulter-Nile    Australia               NaN
# 88        14      FA2        Navdeep Saini        India              DDCA
# 108       18     UFA2          Kuldeep Sen        India              MPCA
# 114       19      BA3           Karun Nair        India              KSCA
# ...

# %%
df
# Out:
#    Set No. Set Name Player Country State Association  Age Specialism Batting  \
# a      NaN      NaN    NaN     NaN               NaN  NaN        NaN     NaN
# b      NaN      NaN    NaN     NaN               NaN  NaN        NaN     NaN
# c      NaN      NaN    NaN     NaN               NaN  NaN        NaN     NaN
#
#   Bowling  IPL Previous IPLTeam(s) 2021 Team C/U/A Base Price Sold Price  \
# a     NaN  NaN                 NaN       NaN   NaN        NaN        NaN
# b     NaN  NaN                 NaN       NaN   NaN        NaN        NaN
# c     NaN  NaN                 NaN       NaN   NaN        NaN        NaN
#
#   New Franchise
# a           NaN
# b           NaN
# c           NaN

# %%
df.loc[(df['New Franchise']=='Rajasthan Royals') & (df['IPL']==38)]
# Out:
#     Set No. Set Name               Player    Country State Association  Age  \
# 87       14      FA2  Nathan Coulter-Nile  Australia               NaN   34
#
#    Specialism Batting                Bowling   IPL Previous IPLTeam(s)  \
# 87     BOWLER     RHB  RIGHT ARM Fast Medium  38.0    DD, KKR, RCB, MI
#
#    2021 Team   C/U/A Base Price Sold Price     New Franchise
# 87        MI  Capped       2 CR       2 CR  Rajasthan Royals

# %%
df
# Out:
#      Set No. Set Name           Player       Country State Association  Age  \
# 0          1        M         R Ashwin         India              TNCA   35
# 1          1        M      Trent Boult   New Zealand               NaN   32
# 2          1        M      Pat Cummins     Australia               NaN   28
# 3          1        M   Shikhar Dhawan         India              DDCA   36
# 4          1        M   Faf Du Plessis  South Africa               NaN   37
# ..       ...      ...              ...           ...               ...  ...
# 179       53     UAL8       Ansh Patel         India               BCA   20
# 180       54     UFA8     Ashok Sharma         India               RCA   19
# 181       57    UAL10  Arjun Tendulkar         India               MCA   22
# 182       59    UAL12  Shubham Garhwal         India               RCA   26
# 183       60    UAL13     Anunay Singh         India              BICA   29
#
# ...

# %%
df.loc[(df['New Franchise']=='Rajasthan Royals') & (df['Sold Price']=='20 L')]
# Out:
#      Set No. Set Name           Player Country State Association  Age  \
# 108       18     UFA2      Kuldeep Sen   India              MPCA   25
# 139       26     UWK2      Dhruv Jurel   India              UPCA   21
# 148       28     USP2     Tejas Baroka   India              DDCA   26
# 161       35     UFA4     Kuldip Yadav   India              DDCA   25
# 182       59    UAL12  Shubham Garhwal   India               RCA   26
# 183       60    UAL13     Anunay Singh   India              BICA   29
#
#        Specialism Batting                 Bowling  IPL Previous IPLTeam(s)  \
# 108        BOWLER     RHB   RIGHT ARM Fast Medium  NaN                 NaN
# 139  WICKETKEEPER     RHB                       -  NaN                 NaN
# 148        BOWLER     RHB      RIGHT ARM Leg Spin  1.0                  GL
# 161        BOWLER     LHB           LEFT ARM Fast  1.0                 NaN
# 182   ALL-ROUNDER     LHB  LEFT ARM Slow Orthodox  NaN                 NaN
# ...

# %%
#base price 20 L and age is above 30 and Team mi
df.loc[(df['Base Price']=='20 L')& (df['Age']<30) &(df['New Franchise']=='Mumbai Indians')]
# Out:
#      Set No. Set Name            Player       Country State Association  Age  \
# 42         7     UBA1     Dewald Brevis  South Africa               NaN   18
# 46         7     UBA1  Anmolpreet Singh         India               PCA   24
# 106       17     UAL2      Sanjay Yadav         India              TNCA   26
# 138       25     UAL3   Ramandeep Singh         India               PCA   24
# 140       26     UWK2       Aryan Juyal         India              UPCA   20
# 156       32     UBA4      Rahul Buddhi         India              HYCA   24
# 172       48     UAL6   Hrithik Shokeen         India              DDCA   21
# 181       57    UAL10   Arjun Tendulkar         India               MCA   22
#
#        Specialism Batting                 Bowling  IPL Previous IPLTeam(s)  \
# 42        BATSMAN     RHB      RIGHT ARM Leg Spin  NaN                 NaN
# 46        BATSMAN     RHB      RIGHT ARM Off Spin  1.0                  MI
# ...

# %%
df.iloc[[0,5],[0,2]]
# Out:
#    Set No.        Player
# 0        1      R Ashwin
# 5        1  Shreyas Iyer

# %%
df['New Franchise'].value_counts()
# Out:
# Kolkata Knight Riders          20
# Punjab Kings                   20
# Rajasthan Royals               19
# Royal Challengers Bangalore    19
# Sunrisers Hyderabad            19
# Mumbai Indians                 19
# Delhi Capitals                 18
# Chennai Super Kings            17
# Gujarat Titans                 16
# Lucknow Super Giants           15
# Luknow Super Giants             1
# Gujarat Titan                   1
# Name: New Franchise, dtype: int64

# %%
for index,row in df.iterrows():
  print(index,row)
# Out:
# 0 Set No.                                 1
# Set Name                                M
# Player                           R Ashwin
# Country                             India
# State Association                    TNCA
# Age                                    35
# Specialism                    ALL-ROUNDER
# Batting                               RHB
# Bowling                RIGHT ARM Off Spin
# IPL                                 167.0
# Previous IPLTeam(s)    CSK, RSP, KXIP, DC
# 2021 Team                              DC
# C/U/A                              Capped
# Base Price                           2 CR
# Sold Price                           5 CR
# New Franchise            Rajasthan Royals
# Name: 0, dtype: object
# 1 Set No.                                   1
# Set Name                                  M
# Player                          Trent Boult
# Country                         New Zealand
# State Association                       NaN
# ...

# %%
df.head()
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M        R Ashwin         India              TNCA   35
# 1        1        M     Trent Boult   New Zealand               NaN   32
# 2        1        M     Pat Cummins     Australia               NaN   28
# 3        1        M  Shikhar Dhawan         India              DDCA   36
# 4        1        M  Faf Du Plessis  South Africa               NaN   37
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0  ALL-ROUNDER     RHB    RIGHT ARM Off Spin  167.0  CSK, RSP, KXIP, DC
# 1       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# 2  ALL-ROUNDER     RHB        RIGHT ARM Fast   37.0         DD, MI, KKR
# 3      BATSMAN     LHB                     -  192.0    DCH, MI, SRH, DC
# 4      BATSMAN     RHB    RIGHT ARM Leg Spin  100.0            RPS, CSK
#
#   2021 Team   C/U/A Base Price Sold Price                New Franchise
# ...

# %%
df.groupby(["State Association"]).mean()
# Out:
#                      Set No.        Age         IPL
# State Association
# ACA                 5.500000  31.000000  175.000000
# ASCA                8.000000  20.000000   30.000000
# BCA                28.000000  25.500000   84.000000
# BICA               60.000000  29.000000         NaN
# CAB                15.400000  27.200000   22.750000
# CSCSCA             48.000000  30.000000    0.000000
# DDCA               22.384615  25.153846   38.555556
# GCA                25.000000  24.000000    0.000000
# GUCA               17.000000  26.000000    2.000000
# HCA                 7.500000  30.500000   61.000000
# HPCA               23.500000  28.000000   13.000000
# HYCA               29.500000  25.500000    0.000000
# JKCA               27.000000  22.000000    1.000000
# JSCA               18.750000  27.500000   46.000000
# KCA                 7.000000  30.666667   72.000000
# KSCA               16.166667  26.916667   47.750000
# MACA               17.000000  23.500000   62.000000
# ...

# %%
df.groupby(["New Franchise"]).mean()
# Out:
#                                Set No.        Age        IPL
# New Franchise
# Chennai Super Kings          15.294118  28.470588  65.000000
# Delhi Capitals               14.111111  26.222222  35.571429
# Gujarat Titan                30.000000  31.000000  41.000000
# Gujarat Titans               14.062500  28.312500  31.538462
# Kolkata Knight Riders        22.700000  27.400000  41.928571
# Lucknow Super Giants         17.933333  28.133333  49.090909
# Luknow Super Giants          27.000000  23.000000   0.000000
# Mumbai Indians               22.157895  25.105263  19.642857
# Punjab Kings                 18.800000  27.200000  34.000000
# Rajasthan Royals             18.578947  27.421053  47.692308
# Royal Challengers Bangalore  16.157895  27.368421  32.529412
# Sunrisers Hyderabad          17.578947  25.894737  27.000000

# %%
df.groupby(["Country"]).sum().sort_values("IPL",ascending=False)
# Out:
#               Set No.   Age     IPL
# Country
# India            2353  3229  3906.0
# Australia         179   360   282.0
# West Indies       249   381   276.0
# South Africa       56   194   247.0
# New Zealand       192   319   158.0
# England           173   340   146.0
# Bangladesh          5    26    38.0
# Sri Lanka          70   100     2.0
# Afghanistan        33    38     0.0

# %%
df['Specialism'].unique()
# Out:
# array(['ALL-ROUNDER', 'BOWLER', 'BATSMAN', 'WICKETKEEPER'], dtype=object)

# %%
df['Specialism'].nunique()
# Out:
# 4
